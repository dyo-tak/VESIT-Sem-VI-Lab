# %%
install.packages("googleDrive")
install.packages("googlesheets")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘googleDrive’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Warning message:
# “Perhaps you meant ‘googledrive’ ?”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘googlesheets’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %%
library(googleDrive)
drive_auth()
# Out:
# Error in library(googleDrive): there is no package called ‘googleDrive’
# Traceback:
#
# 1. library(googleDrive)
