# %%
import pandas as pd

# %%
deliveries = pd.read_csv('../data/raw/deliveries.csv')
deliveries['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],
#       dtype=object)

# %%
mi_csk = deliveries[(deliveries['batting_team'].isin(['Mumbai Indians', 'Chennai Super Kings']))]

# %%
mi_csk = mi_csk[(mi_csk['bowling_team'].isin(['Mumbai Indians', 'Chennai Super Kings']))]

# %%
mi_csk = mi_csk.drop([ 'batsman', 'non_striker', 'bowler', 'batsman_runs','is_super_over', 'wide_runs', 'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs', 'extra_runs', 'player_dismissed', 'dismissal_kind', 'fielder'], axis=1)
mi_csk.head(2)
# Out:
#        match_id  inning         batting_team    bowling_team  over  ball  \
# 15486        67       1  Chennai Super Kings  Mumbai Indians     1     1
# 15487        67       1  Chennai Super Kings  Mumbai Indians     1     2
#
#        total_runs
# 15486           1
# 15487           0

# %%
mi_csk['batting_team'].unique()
mi_csk['bowling_team'].unique()
# Out:
# array(['Mumbai Indians', 'Chennai Super Kings'], dtype=object)

# %%
mi_csk = pd.get_dummies(mi_csk, columns=['batting_team'], prefix=['batting_team'])

# %%
mi_csk.drop(['batting_team_Chennai Super Kings', 'bowling_team'], axis=1, inplace=True)

# %%
mi_csk = mi_csk.replace({True: 1, False: 0})

# %%
mi_csk.head(20)
# Out:
#        ordered_match_id  mi_batting  inning  over  ball  total_runs  \
# 15486                 1           0       1     1     1           1
# 15487                 1           0       1     1     2           0
# 15488                 1           0       1     1     3           0
# 15489                 1           0       1     1     4           0
# 15490                 1           0       1     1     5           4
# 15491                 1           0       1     1     6           0
# 15492                 1           0       1     1     7           2
# 15493                 1           0       1     2     1           0
# 15494                 1           0       1     2     2           1
# 15495                 1           0       1     2     3           0
# 15496                 1           0       1     2     4           4
# 15497                 1           0       1     2     5           0
# 15498                 1           0       1     2     6           4
# ...

# %%
mi_csk.to_csv('../data/cleaned/mi_csk.csv', index=False)

# %%
mi_csk = mi_csk.rename(columns={'ordered_match_id': 'match_id'})

# %%
df = mi_csk
df['team_score'] = df.groupby(['inning', 'match_id'])['total_runs'].cumsum()

# %%
df.head(20)
# Out:
#        match_id  inning  over  ball  total_runs  batting_team_Mumbai Indians  \
# 15486        67       1     1     1           1                            0
# 15487        67       1     1     2           0                            0
# 15488        67       1     1     3           0                            0
# 15489        67       1     1     4           0                            0
# 15490        67       1     1     5           4                            0
# 15491        67       1     1     6           0                            0
# 15492        67       1     1     7           2                            0
# 15493        67       1     2     1           0                            0
# 15494        67       1     2     2           1                            0
# 15495        67       1     2     3           0                            0
# 15496        67       1     2     4           4                            0
# ...

# %%
df.rename(columns={'batting_team_Mumbai Indians': 'mi_batting'}, inplace=True)

# %%
mi_csk = df[['ordered_match_id', 'mi_batting', 'inning', 'over', 'ball', 'total_runs', 'team_score']]

# %%
pd.factorize(df['match_id'])[0] + 1
# Out:
# array([ 1,  1,  1, ..., 22, 22, 22], dtype=int64)

# %%
df['ordered_match_id'] = pd.factorize(df['match_id'])[0] + 1

# %%
df.head([150,200])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 df.head([150,200])
#
# File c:\Users\dyota\anaconda3\envs\ml\Lib\site-packages\pandas\core\generic.py:5804, in NDFrame.head(self, n)
#    5802 if using_copy_on_write():
#    5803     return self.iloc[:n].copy()
# -> 5804 return self.iloc[:n]
#
# File c:\Users\dyota\anaconda3\envs\ml\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\dyota\anaconda3\envs\ml\Lib\site-packages\pandas\core\indexing.py:1691, in _iLocIndexer._getitem_axis(self, key, axis)
#    1685     raise IndexError(
#    1686         "DataFrame indexer is not allowed for .iloc\n"
# ...

# %%
df['match_id'].unique().shape
# Out:
# (22,)
